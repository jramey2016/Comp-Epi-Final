# %% [markdown]
# # China influenza models
#
# #### Data collected from the WHO [source](https://app.powerbi.com/view?r=eyJrIjoiNjViM2Y4NjktMjJmMC00Y2NjLWFmOWQtODQ0NjZkNWM1YzNmIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9)

# %%
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # China 2015-2019 Influenza Cases

# %%
# Load the data from the Excel file
df_2015_to_2019 = pd.read_excel('China_2015-2019_influenza_Data.xlsx', engine='openpyxl')
df_2015_to_2019[['INF_ALL', 'INF_A', 'INF_B']] = df_2015_to_2019[['INF_ALL', 'INF_A', 'INF_B']].fillna(0)
# Group the data by year and ISO_WEEK, calculate the sum (sentinel and non-sentinel) of INF_ALL 
df_agg9 = df_2015_to_2019.groupby(['ISO_YEAR', 'ISO_SDATE']).agg({'INF_ALL': 'sum', 'INF_A': 'sum', 'INF_B': 'sum'}).reset_index()

# Extract only the date portion
df_agg9['ISO_SDATE'] = df_agg9['ISO_SDATE'].str.split('T').str[0]

# Create a plot
plt.figure(figsize=(16, 6))
plt.plot(df_agg9['ISO_SDATE'], df_agg9['INF_ALL'], label='Cumulative Cases')
plt.plot(df_agg9['ISO_SDATE'], df_agg9['INF_A'], label='Influenza A Cases')
plt.plot(df_agg9['ISO_SDATE'], df_agg9['INF_B'], label='Influenza B Cases')

plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('China - Influenza Cases from 2015 to 2019')

xtick_pos = np.arange(0, len(df_agg9['ISO_SDATE']), 20)
plt.xticks(xtick_pos, df_agg9['ISO_SDATE'][xtick_pos], rotation=45)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 2015 - 2022 influenza cases

# %%
# Load the data from the Excel file
df_2015_to_2022 = pd.read_excel('China_2015-2022_influenza_Data.xlsx', engine='openpyxl')
df_2015_to_2022[['INF_ALL', 'INF_A', 'INF_B']] = df_2015_to_2022[['INF_ALL', 'INF_A', 'INF_B']].fillna(0)

# Group the data by year and ISO_WEEK, calculate the sum (sentinel and non-sentinel) 
df_agg10 = df_2015_to_2022.groupby(['ISO_YEAR', 'ISO_SDATE']).agg({'INF_ALL': 'sum', 'INF_A': 'sum', 'INF_B': 'sum'}).reset_index()

# Extract only the date portion 
df_agg10['ISO_SDATE'] = df_agg10['ISO_SDATE'].str.split('T').str[0]

# Create a plot 
plt.figure(figsize=(16, 6))
plt.plot(df_agg10['ISO_SDATE'], df_agg10['INF_ALL'], label='Cumulative Cases')
plt.plot(df_agg10['ISO_SDATE'], df_agg10['INF_A'], label='Influenza A Cases')
plt.plot(df_agg10['ISO_SDATE'], df_agg10['INF_B'], label='Influenza B Cases')

plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('China - Influenza Cases from 2015 to 2022')

xtick_pos = np.arange(0, len(df_agg10['ISO_SDATE']), 40)
plt.xticks(xtick_pos, df_agg10['ISO_SDATE'][xtick_pos], rotation=45)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 2020 - 2022 influenza cases

# %%
# Load the data from the Excel file
df_2020_to_2022 = pd.read_excel('China_2020-2022_influenza_Data.xlsx', engine='openpyxl')
df_2020_to_2022[['INF_ALL', 'INF_A', 'INF_B']] = df_2020_to_2022[['INF_ALL', 'INF_A', 'INF_B']].fillna(0)
# Group the data by year and ISO_WEEK, calculate the sum (sentinel and non-sentinel) of INF_ALL 
df_agg11 = df_2020_to_2022.groupby(['ISO_YEAR', 'ISO_SDATE']).agg({'INF_ALL': 'sum', 'INF_A': 'sum', 'INF_B': 'sum'}).reset_index()

# Extract only the date portion of ISO_SDATE column
df_agg11['ISO_SDATE'] = df_agg11['ISO_SDATE'].str.split('T').str[0]

# Create a line plot using ISO_WEEK as the x-axis and INF_ALL as the y-axis
plt.figure(figsize=(16, 6))
plt.plot(df_agg11['ISO_SDATE'], df_agg11['INF_ALL'], label='Cumulative Cases')
plt.plot(df_agg11['ISO_SDATE'], df_agg11['INF_A'], label='Influenza A Cases')
plt.plot(df_agg11['ISO_SDATE'], df_agg11['INF_B'], label='Influenza B Cases')

plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('China - Influenza Cases from 2020 to 2022')

xtick_pos = np.arange(0, len(df_agg11['ISO_SDATE']), 15)
plt.xticks(xtick_pos, df_agg11['ISO_SDATE'][xtick_pos], rotation=45)

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Noteable Dates

# %%
# Load the data from the Excel file
import datetime as dt
df_2020_to_2022 = pd.read_excel('China_2020-2022_influenza_Data.xlsx', engine='openpyxl')
df_2020_to_2022[['INF_ALL', 'INF_A', 'INF_B']] = df_2020_to_2022[['INF_ALL', 'INF_A', 'INF_B']].fillna(0)
# Group the data by year and ISO_WEEK, calculate the sum (sentinel and non-sentinel) of INF_ALL
df_agg11 = df_2020_to_2022.groupby(['ISO_YEAR', 'ISO_SDATE']).agg({'INF_ALL': 'sum', 'INF_A': 'sum', 'INF_B': 'sum'}).reset_index()

# Extract only the date portion of ISO_SDATE column
df_agg11['ISO_SDATE'] = pd.to_datetime(df_agg11['ISO_SDATE'].str.split('T').str[0])

# Create a line plot using ISO_WEEK as the x-axis and INF_ALL as the y-axis
plt.figure(figsize=(18, 12))

# Add vertical lines for specific dates
plt.plot(df_agg11['ISO_SDATE'], df_agg11['INF_ALL'], label='Cumulative Cases')
plt.plot(df_agg11['ISO_SDATE'], df_agg11['INF_A'], label='Influenza A Cases')
plt.plot(df_agg11['ISO_SDATE'], df_agg11['INF_B'], label='Influenza B Cases')

#important dates
plt.axvline(pd.Timestamp('2020-01-07'), color='black', alpha=0.4)
plt.text(pd.Timestamp('2020-01-07'), 6000, 'January 7, 2020: Chinese health authorities announce that they \nhave identified a new coronavirus', rotation=0, color='black', fontweight='bold')

plt.axvline(pd.Timestamp('2020-01-23'), color='black', alpha=0.4)
plt.text(pd.Timestamp('2020-01-23'), 5500, 'January 23, 2020: Chinese authorities lock down the city of Wuhan, \n where the outbreak began, and surrounding areas \nin an effort to contain the virus.', rotation=0, color='black', fontweight='bold')

plt.axvline(pd.Timestamp('2020-03-11'), color='black', alpha=0.4)
plt.text(pd.Timestamp('2020-03-11'), 5000, 'March 11, 2020: The Chinese government reports that there were no new \nlocally transmitted cases of COVID-19 in \nthe country for the first time since the outbreak began.', rotation=0, color='black', fontweight='bold')

plt.axvline(pd.Timestamp('2020-04-08'), color='black', alpha=0.4)
plt.text(pd.Timestamp('2020-04-08'), 4500, 'April 8, 2020: China ends the lockdown of Wuhan, \nallowing people to leave the city for the first time in 76 days.', rotation=0, color='black', fontweight='bold')

plt.axvline(pd.Timestamp('2020-12-30'), color='black', alpha=0.4)
plt.text(pd.Timestamp('2020-12-30'), 4000, 'December 30, 2020: The Chinese government reports \n its first death from COVID-19 in eight months.', rotation=0, color='black', fontweight='bold')

plt.axvline(pd.Timestamp('2021-01-14'), color='black', alpha=0.4)
plt.text(pd.Timestamp('2021-01-14'), 3500, 'January 14, 2021: Chinese health authorities report the first local \ntransmission of COVID-19 in more than \nsix months in Hebei province, which surrounds Beijing.', rotation=0, color='black', fontweight='bold')

plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('China - Influenza Cases from 2020 to 2022')

plt.xlim(df_agg11['ISO_SDATE'].min(), df_agg11['ISO_SDATE'].max())

xtick_pos = np.arange(0, len(df_agg11['ISO_SDATE']), 1)
plt.xticks(xtick_pos, df_agg11['ISO_SDATE'][xtick_pos], rotation=45)

plt.legend()

# Clip x-axis to the first and last data points
plt.gca().set_xlim(left=df_agg11['ISO_SDATE'].iloc[0], right=df_agg11['ISO_SDATE'].iloc[-1])

plt.show()

# %% [markdown]
# # China 2020-2022 influenza cases with Sample collection

# %%
# Load the data from the Excel file
df_2020_to_2022 = pd.read_excel('China_2020-2022_influenza_Data.xlsx', engine='openpyxl')

# Group the data by year and ISO_WEEK, calculate the sum (sentinel and non-sentinel) of INF_ALL
df_agg11 = df_2020_to_2022.groupby(['ISO_YEAR', 'ISO_SDATE']).agg({'INF_ALL': 'sum', 'INF_A': 'sum', 'INF_B': 'sum'}).reset_index()

df_agg_samples = df_2020_to_2022.groupby(['ISO_YEAR','ISO_SDATE']).agg({'SPEC_PROCESSED_NB' :'sum'}).reset_index()
# # Extract only the date portion of ISO_SDATE column
df_agg11['ISO_SDATE'] = df_agg11['ISO_SDATE'].str.split('T').str[0]
df_agg_samples['ISO_SDATE'] = df_agg_samples['ISO_SDATE'].str.split('T').str[0]
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 16))

# Plot the line graphs in the first subplot
ax1.plot(df_agg11['ISO_SDATE'], df_agg11['INF_ALL'], label='Cumulative Cases')
ax1.plot(df_agg11['ISO_SDATE'], df_agg11['INF_A'], label='Influenza A Cases')
ax1.plot(df_agg11['ISO_SDATE'], df_agg11['INF_B'], label='Influenza B Cases')
ax1.set_xlabel('DATE')
ax1.set_ylabel('Number of Cases')
ax1.set_title('China - Influenza Cases from 2020 to 2022')
xtick_pos = np.arange(0, len(df_agg11['ISO_SDATE']), 10)
ax1.set_xticks(xtick_pos)
ax1.set_xticklabels(df_agg11['ISO_SDATE'][xtick_pos], rotation=45)
ax1.legend()
ax1.grid()

# Plot the bar graph in the second subplot
ax2.bar(df_agg_samples['ISO_SDATE'], df_agg_samples['SPEC_PROCESSED_NB'], label='Samples Process')
ax2.set_xlabel('DATE')
ax2.set_ylabel('Number of Samples')
ax2.set_title('China - Samples Processed from 2020 to 2022')
xtick_pos = np.arange(0, len(df_agg_samples['ISO_SDATE']), 10)
ax2.set_xticks(xtick_pos)
ax2.set_xticklabels(df_agg_samples['ISO_SDATE'][xtick_pos], rotation=45)
ax2.legend()
ax2.grid()

# Adjust the spacing between the subplots
fig.subplots_adjust(hspace=0.4)

# Show the combined graph with both line and bar plots
plt.show()
